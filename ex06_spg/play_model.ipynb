# %%
import gym
from gym import wrappers
from model import PolicyNet, ValueNet
import torch
from torch.distributions import Categorical

policy_net = PolicyNet()
value_net = ValueNet()

state = torch.load("./model.pt")
policy_net.load_state_dict(state["policy"])
value_net.load_state_dict(state["value"])

env = gym.make('CartPole-v1')
env = wrappers.Monitor(env, "./gym-results", force=True)
obs = env.reset()
for _ in range(1000):
    action = Categorical(logits=policy_net(torch.tensor(obs, dtype=torch.float32))).sample().item()
    obs, reward, done, info = env.step(action)
    if done: break
env.close()

# %%
import io
import base64
from IPython.display import HTML

video = io.open('./gym-results/openaigym.video.%s.video000000.mp4' % env.file_infix, 'r+b').read()
encoded = base64.b64encode(video)
HTML(data='''
    <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,{0}" type="video/mp4" /></video>'''
.format(encoded.decode('ascii')))
# Out:
#     <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video>
